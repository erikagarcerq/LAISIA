# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
pic = plt.imread('/content/Y97.JPG')
plt.imshow(pic)

# %%
#Transformar pixels imagem de matriz em vetor linha
pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
pic_n.shape
# Out:
# (96560, 3)

# %%
#escolher 3 clusters: subs branca, negra e background.
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3).fit(pic_n)
pic2show = kmeans.cluster_centers_[kmeans.labels_]

# %%
pic.shape[0]
# Out:
# 355

# %%
pic.shape[1]
# Out:
# 272

# %%
pic.shape[2]
# Out:
# 3

# %%
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
plt.imshow(cluster_pic)

# %%
# definindo unidade limiar
pic = plt.imread('/content/Y97.JPG')
img_gray = cv2.cvtColor(pic, cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(img_gray,120,255,cv2.THRESH_BINARY)
plt.imshow(thresh)

# %%
ret, markers = cv2.connectedComponents(thresh)
#Soma dos elementos da matriz em um determinado eixo- np.sum(markers==m).

#Obtendo a área ocupada por cada componente.

area_marcada = [np.sum(markers==m) for m in range(np.max(markers)) if m!=0] # Ignorar o label 0, pois é o plano de fundo.
maior_comp = np.argmax(area_marcada)+1 
brain_mask = markers==largest_component

brain_out[brain_mask==False] = (0,0,0)
plt.imshow(brain_out)
